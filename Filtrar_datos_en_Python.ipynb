# %% [markdown]
# <a href="https://colab.research.google.com/github/luisosmx/Python-for-data-science-and-big-data-essential/blob/main/Filtrar_datos_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/airline_dec_2008_50k.csv')
# Out:
# <ipython-input-1-dcc53ca8087d>:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/airline_dec_2008_50k.csv')

# %%
df['ArrDelay'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: ArrDelay, dtype: float64

# %%
df[100:110]
# Out:
#      Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 100         101  2008     12           1          1      NaN        1415
# 101         102  2008     12           1          1      NaN        1418
# 102         103  2008     12           1          1      NaN        1425
# 103         104  2008     12           1          1      NaN        1426
# 104         105  2008     12           1          1      NaN        1429
# 105         106  2008     12           1          1      NaN        1430
# 106         107  2008     12           1          1      NaN        1430
# 107         108  2008     12           1          1      NaN        1430
# 108         109  2008     12           1          1      NaN        1433
# 109         110  2008     12           1          1      NaN        1435
#
#      ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 100      NaN        1525            OO  ...     NaN     NaN          1
# ...

# %%
df[df['ArrDelay'] > 60].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 18605       18606  2008     12           1          1     15.0        2115
# 18623       18624  2008     12          14          7      4.0        2220
# 18624       18625  2008     12          18          4      3.0        2310
# 18629       18630  2008     12          20          6      4.0        2250
# 18632       18633  2008     12          22          1      2.0        2306
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 18605    329.0           5            MQ  ...     3.0    46.0          0
# 18623    151.0           6            UA  ...     4.0    26.0          0
# 18624    107.0           5            AA  ...     6.0    17.0          0
# 18629    110.0           8            UA  ...    11.0    14.0          0
# 18632    106.0           5            AS  ...     6.0    13.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[df['ArrDelay'] == 60].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 20310       20311  2008     12           1          1    631.0         600
# 20602       20603  2008     12           1          1    654.0         600
# 21053       21054  2008     12           1          1    728.0         645
# 21311       21312  2008     12           1          1    756.0         728
# 24475       24476  2008     12          23          2      6.0        2325
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 20310    841.0         741            DL  ...    20.0    17.0          0
# 20602    927.0         827            XE  ...    12.0    10.0          0
# 21053    740.0         640            OO  ...    17.0    10.0          0
# 21311    929.0         829            OO  ...    31.0    12.0          0
# 24475    822.0         722            B6  ...     8.0    17.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[df['ArrDelay'] != 60].head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           1  2008     12           1          1      NaN        1000
# 1           2  2008     12           1          1      NaN        1000
# 2           3  2008     12           1          1      NaN        1000
# 3           4  2008     12           1          1      NaN        1000
# 4           5  2008     12           1          1      NaN        1000
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0      NaN        1100            WN  ...     NaN     NaN          1
# 1      NaN        1110            US  ...     NaN     NaN          1
# 2      NaN        1125            MQ  ...     NaN     NaN          1
# 3      NaN        1227            EV  ...     NaN     NaN          1
# 4      NaN        1227            NW  ...     NaN     NaN          1
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[df['ArrDelay'] >= 60].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 18605       18606  2008     12           1          1     15.0        2115
# 18623       18624  2008     12          14          7      4.0        2220
# 18624       18625  2008     12          18          4      3.0        2310
# 18629       18630  2008     12          20          6      4.0        2250
# 18632       18633  2008     12          22          1      2.0        2306
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 18605    329.0           5            MQ  ...     3.0    46.0          0
# 18623    151.0           6            UA  ...     4.0    26.0          0
# 18624    107.0           5            AA  ...     6.0    17.0          0
# 18629    110.0           8            UA  ...    11.0    14.0          0
# 18632    106.0           5            AS  ...     6.0    13.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[df['Origin'] == 'ATL'].head()
# Out:
#      Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 19           20  2008     12           1          1      NaN        1100
# 36           37  2008     12           1          1      NaN        1140
# 92           93  2008     12           1          1      NaN        1346
# 124         125  2008     12           1          1      NaN        1451
# 244         245  2008     12           1          1      NaN        1910
#
#      ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 19       NaN        1207            EV  ...     NaN     NaN          1
# 36       NaN        1230            FL  ...     NaN     NaN          1
# 92       NaN        1448            FL  ...     NaN     NaN          1
# 124      NaN        1630            EV  ...     NaN     NaN          1
# 244      NaN        2059            YV  ...     NaN     NaN          1
#
#      CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[(df['Origin']  == 'ATL') & (df['ArrDelay'] > 60)].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 18828       18829  2008     12           1          1     22.0        2150
# 19123       19124  2008     12          26          5      8.0        2119
# 19295       19296  2008     12           5          5      4.0        2230
# 19319       19320  2008     12           7          7     19.0        2239
# 19382       19383  2008     12           9          2      9.0        2120
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 18828      8.0        2149            EV  ...     4.0    13.0          0
# 19123      9.0        2111            EV  ...     3.0    28.0          0
# 19295     59.0        2335            DL  ...     4.0    11.0          0
# 19319    153.0          19            DL  ...     4.0    12.0          0
# 19382     54.0        2219            DL  ...    11.0    10.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[(df['Origin']  == 'ATL') | (df['ArrDelay'] > 60)].head()
# Out:
#      Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 19           20  2008     12           1          1      NaN        1100
# 36           37  2008     12           1          1      NaN        1140
# 92           93  2008     12           1          1      NaN        1346
# 124         125  2008     12           1          1      NaN        1451
# 244         245  2008     12           1          1      NaN        1910
#
#      ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 19       NaN        1207            EV  ...     NaN     NaN          1
# 36       NaN        1230            FL  ...     NaN     NaN          1
# 92       NaN        1448            FL  ...     NaN     NaN          1
# 124      NaN        1630            EV  ...     NaN     NaN          1
# 244      NaN        2059            YV  ...     NaN     NaN          1
#
#      CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[df.Origin.isin(['HOU' , 'ATL'])].head()
# Out:
#     Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0            1  2008     12           1          1      NaN        1000
# 19          20  2008     12           1          1      NaN        1100
# 36          37  2008     12           1          1      NaN        1140
# 83          84  2008     12           1          1      NaN        1325
# 92          93  2008     12           1          1      NaN        1346
#
#     ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0       NaN        1100            WN  ...     NaN     NaN          1
# 19      NaN        1207            EV  ...     NaN     NaN          1
# 36      NaN        1230            FL  ...     NaN     NaN          1
# 83      NaN        1435            MQ  ...     NaN     NaN          1
# 92      NaN        1448            FL  ...     NaN     NaN          1
#
#     CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df[pd.isna(df['ArrDelay'])].head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           1  2008     12           1          1      NaN        1000
# 1           2  2008     12           1          1      NaN        1000
# 2           3  2008     12           1          1      NaN        1000
# 3           4  2008     12           1          1      NaN        1000
# 4           5  2008     12           1          1      NaN        1000
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0      NaN        1100            WN  ...     NaN     NaN          1
# 1      NaN        1110            US  ...     NaN     NaN          1
# 2      NaN        1125            MQ  ...     NaN     NaN          1
# 3      NaN        1227            EV  ...     NaN     NaN          1
# 4      NaN        1227            NW  ...     NaN     NaN          1
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
len(df[pd.isna(df['ArrDelay'])])
# Out:
# 18633
