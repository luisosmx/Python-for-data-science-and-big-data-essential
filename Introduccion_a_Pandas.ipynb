# %% [markdown]
# <a href="https://colab.research.google.com/github/luisosmx/Python-for-data-science-and-big-data-essential/blob/main/Introduccion_a_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/airline_dec_2008_50k.csv', nrows = 100000)
# Out:
# <ipython-input-2-2f9d7442c16a>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/airline_dec_2008_50k.csv', nrows = 100000)

# %%
df.head(10)
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           1  2008     12           1          1      NaN        1000
# 1           2  2008     12           1          1      NaN        1000
# 2           3  2008     12           1          1      NaN        1000
# 3           4  2008     12           1          1      NaN        1000
# 4           5  2008     12           1          1      NaN        1000
# 5           6  2008     12           1          1      NaN        1005
# 6           7  2008     12           1          1      NaN        1015
# 7           8  2008     12           1          1      NaN        1020
# 8           9  2008     12           1          1      NaN        1029
# 9          10  2008     12           1          1      NaN        1030
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0      NaN        1100            WN  ...     NaN     NaN          1
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 49995       49996  2008     12          13          6    805.0         810
# 49996       49997  2008     12          13          6    805.0         810
# 49997       49998  2008     12          13          6    805.0         810
# 49998       49999  2008     12          13          6    805.0         810
# 49999       50000  2008     12          13          6    806.0         800
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 49995    900.0         904            YV  ...    10.0    16.0          0
# 49996    906.0         916            CO  ...     7.0    13.0          0
# 49997    925.0         940            WN  ...     2.0    10.0          0
# 49998    938.0         945            AA  ...     4.0    14.0          0
# 49999    935.0         935            MQ  ...     9.0    15.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df = df.sample(frac = 1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 32579    611.0
# 8123       NaN
# 15733      NaN
# 7100       NaN
# 31638    748.0
#          ...
# 27094    854.0
# 39099    628.0
# 45604    735.0
# 15716      NaN
# 4537       NaN
# Name: DepTime, Length: 50000, dtype: float64

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[32580, 2008, 12, ..., nan, nan, nan],
#        [8124, 2008, 12, ..., nan, nan, nan],
#        [15734, 2008, 12, ..., nan, nan, nan],
#        ...,
#        [45605, 2008, 12, ..., 22.0, 0.0, 0.0],
#        [15717, 2008, 12, ..., nan, nan, nan],
#        [4538, 2008, 12, ..., nan, nan, nan]], dtype=object)

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 32579       32580  2008     12           6          6    611.0         613
# 8123         8124  2008     12          19          5      NaN        1656
# 15733       15734  2008     12          27          6      NaN         754
# 7100         7101  2008     12          18          4      NaN         820
# 31638       31639  2008     12           5          5    748.0         745
# 1047         1048  2008     12           5          5      NaN        1530
# 43347       43348  2008     12          11          4    557.0         600
# 5985         5986  2008     12          17          3      NaN        2034
# 8499         8500  2008     12          19          5      NaN        1935
# 10564       10565  2008     12          21          7      NaN        1510
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# ...
